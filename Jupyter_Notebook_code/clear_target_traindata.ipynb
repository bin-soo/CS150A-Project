# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn
import random

# %%
train_filepath = 'data/target_train.csv'
traindata = pd.read_csv(train_filepath)

# %%
traindata
# Out:
#         Unnamed: 0      Row  Anon Student Id  Problem Hierarchy  Problem Name  \
# 0                0     9938         0.748749           0.780822      0.710714
# 1                1     9939         0.748749           0.780822      0.710714
# 2                2     9940         0.748749           0.780822      0.710714
# 3                3     9941         0.748749           0.780822      0.710714
# 4                4     9942         0.748749           0.780822      0.710714
# ...            ...      ...              ...                ...           ...
# 232739      232739  1078856         0.721311           0.780876      0.771429
# 232740      232740  1078857         0.721311           0.780876      0.771429
# 232741      232741  1078858         0.721311           0.780876      0.771429
# 232742      232742  1078859         0.721311           0.780876      0.771429
# 232743      232743  1078860         0.721311           0.780876      0.771429
#
# ...

# %%
reference_path = 'data/clear_train.csv'
reference = pd.read_csv(reference_path)

# %%
reference
# Out:
#         Unnamed: 0      Row  Unnamed: 0.1 Anon Student Id  \
# 0                0     9938             0      52vEY7f17k
# 1                1     9939             1      52vEY7f17k
# 2                2     9940             2      52vEY7f17k
# 3                3     9941             3      52vEY7f17k
# 4                4     9942             4      52vEY7f17k
# ...            ...      ...           ...             ...
# 232739      232739  1078856        232739      JP20cryBg8
# 232740      232740  1078857        232740      JP20cryBg8
# 232741      232741  1078858        232741      JP20cryBg8
# 232742      232742  1078859        232742      JP20cryBg8
# 232743      232743  1078860        232743      JP20cryBg8
#
#                       Problem Hierarchy Problem Name  Problem View Step Name  \
# 0       Unit CTA1_13, Section CTA1_13-1       PROP04             1      R1C1
# 1       Unit CTA1_13, Section CTA1_13-1       PROP04             1      R1C2
# ...

# %%
tlist = [i for i in range(232744)]
newdata = pd.DataFrame(columns = ["A"], index = tlist)
newdata.insert(0, "Anon Student Id", traindata["Anon Student Id"])
del newdata["A"]

# %%
newdata.insert(1, "Problem Hierarchy", traindata["Problem Hierarchy"])
newdata.insert(2, "Problem Name", traindata["Problem Name"])
newdata.insert(3, "Problem View", traindata["Problem View"])
newdata.insert(4, "Step Name", traindata["Step Name"])
newdata.insert(5, "KC(Default)", traindata["KC(Default)"])
newdata.insert(6, "Opportunity(Default)", traindata["Opportunity(Default)"])
newdata.insert(7, "CFAR (Anon Student Id)", reference["CFAR (Anon Student Id)"])
newdata.insert(8, "CFAR (Problem Name)", reference["CFAR (Problem Name)"])
newdata.insert(9, "CFAR (Step Name)", reference["CFAR (Step Name)"])
newdata.insert(10, "CFAR (Problem Hierarchy)",reference["CFAR (Problem Hierarchy)"])
newdata.insert(11, "Step Duration (Anon Student Id)", reference["Step Duration (Anon Student Id)"])
newdata.insert(12, "Step Duration (Problem Name)", reference["Step Duration (Problem Name)"])
newdata.insert(13, "Step Duration (Step Name)", reference["Step Duration (Step Name)"])
newdata.insert(14, "Step Duration (Problem Hierarchy)", reference["Step Duration (Problem Hierarchy)"])

# %%
del newdata["Opportunity(Default)"]
newdata.insert(6, "Opportunity(Default)", reference["Opportunity(Default)"])

# %%
newdata.insert(0, "Row", reference["Row"])

# %%
newdata.to_csv("data/target_clear_train.csv")

# %%
newdata
# Out:
#             Row  Anon Student Id  Problem Hierarchy  Problem Name  \
# 0          9938         0.748749           0.780822      0.710714
# 1          9939         0.748749           0.780822      0.710714
# 2          9940         0.748749           0.780822      0.710714
# 3          9941         0.748749           0.780822      0.710714
# 4          9942         0.748749           0.780822      0.710714
# ...         ...              ...                ...           ...
# 232739  1078856         0.721311           0.780876      0.771429
# 232740  1078857         0.721311           0.780876      0.771429
# 232741  1078858         0.721311           0.780876      0.771429
# 232742  1078859         0.721311           0.780876      0.771429
# 232743  1078860         0.721311           0.780876      0.771429
#
#         Problem View  Step Name  KC(Default)  Opportunity(Default)  \
# 0                  1   0.840635     0.815118                   NaN
# ...

# %%
#change second time
traindata = pd.read_csv("data/target_clear_train_new.csv")
# Out:
#         Unnamed: 0      Row  Anon Student Id  Problem Hierarchy  Problem Name  \
# 0                0     9938         0.748749           0.780822      0.710714
# 1                1     9939         0.748749           0.780822      0.710714
# 2                2     9940         0.748749           0.780822      0.710714
# 3                3     9941         0.748749           0.780822      0.710714
# 4                4     9942         0.748749           0.780822      0.710714
# ...            ...      ...              ...                ...           ...
# 232739      232739  1078856         0.721311           0.780876      0.771429
# 232740      232740  1078857         0.721311           0.780876      0.771429
# 232741      232741  1078858         0.721311           0.780876      0.771429
# 232742      232742  1078859         0.721311           0.780876      0.771429
# 232743      232743  1078860         0.721311           0.780876      0.771429
#
# ...

# %%
traindata = traindata.fillna(0)

# %%
traindata.to_csv("data/target_clear_train_new.csv")
